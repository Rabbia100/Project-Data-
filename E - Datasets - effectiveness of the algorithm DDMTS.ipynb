# %% [markdown]
# # Synthetic Datasets E-SYN* for checking the efficiency of the Algorithm DDMTS

# %% [markdown]
# ## E- SYN1

# %%
#Required Libraries
import numpy as np
import random
import matplotlib.pyplot as plt

a= np.random.multivariate_normal([0,0],[[0.01,0.008],[0.008,0.01]],size=1000)
z1=a[:,0]
z2=a[:,1]
freq_sample=1000
freq=100
samples=1000
noise=0.00008*np.asarray(random.sample(range(0,1000),samples))

x_input=np.arange(samples)
y_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1

for i in range(len(y_out)):
    if i <= 50:
        y_out[i]=y_out[i]
    
  #  if i < 50:
   #     y_out1[i]=y_out1[i]+60
    


    if i>=51 and i<=56:
        y_out[i]=y_out[i]
    
    if i>=57 and i<=100:
        y_out[i]=y_out[i]

    if i>=101 and i<=104:
        y_out[i]=y_out[i]+16
        
    if i>=110 and i<=120:
        y_out[i]=y_out[i]+16    
    if i>=121 and i<=170:
        y_out[i]=y_out[i]+16    
    if i>=171 and i<=300:
        y_out[i]=y_out[i]    
    
    if i>=301 and i<=350:
        y_out[i]=y_out[i]
        
    
    if i>=351 and i<=600:
        y_out[i]=y_out[i]

    
    if i>=601 and i<=620:
        y_out[i]=y_out[i]+30
    
    
    
    if i>=621 and i<=680:
        y_out[i]=y_out[i]+30
    

    if i>=700 and i<=720:
        y_out[i]=y_out[i]
    
    
    if i>=721 and i<=735:
        y_out[i]=y_out[i]
    
    if i>=737 and i<=739:
        y_out[i]=y_out[i]-19

    if i>=740 and i<=800:
        y_out[i]=y_out[i]



    if i>=801 and i<=900:
        y_out[i]=y_out[i]
     
    if i>=901 and i<=999:
        y_out[i]=y_out[i]
        
        
        

        
for i in range(len(y_out)):
  #  if i < 50:
   #     y_out[i]=y_out[i]+100
    
    if i <= 50:
        y_out1[i]=y_out1[i]
    


    if i>=51 and i<=60:
        y_out1[i]=y_out1[i]
    
    if i>=61 and i<=100:
        y_out1[i]=y_out1[i]


    if i>=101 and i<=104:
        y_out[i]=y_out[i]-16

    if i>=110 and i<=120:
        y_out1[i]=y_out1[i]-16    
    if i>=121 and i<=170:
        y_out1[i]=y_out1[i]-16    
    if i>=171 and i<=300:
        y_out1[i]=y_out1[i]    
    
    if i>=301 and i<=350:
        y_out1[i]=y_out1[i]
        
    
    if i>=351 and i<=600:
        y_out1[i]=y_out1[i]

    
    if i>=601 and i<=620:
        y_out1[i]=y_out1[i]-30
    
    
    
    if i>=621 and i<=680:
        y_out1[i]=y_out1[i]-30
    

    if i>=700 and i<=720:
        y_out1[i]=y_out1[i]
    
    
    if i>=721 and i<=800:
        y_out1[i]=y_out1[i]
    
    if i>=801 and i<900:
        y_out1[i]=y_out1[i]
     
    if i>=901 and i<=905:
        y_out1[i]=y_out1[i]
        
    if i>=986 and i<=989:
        y_out1[i]=y_out1[i]+20
        
    if i>=990 and i<=1000:
        y_out1[i]=y_out1[i]

        
print(y_out.mean())
print(y_out1.mean())  
print(y_out.std())
print(y_out1.std())


plt.figure(figsize=(8, 8))
plt.subplot(2,1,1)      
plt.plot(x_input,y_out)
plt.subplot(2,1,2)
plt.plot(x_input,y_out1)
#plt.plot(x_input,z2)
plt.show()
# Out:
# 3.318347514994976
# -3.294545408423065
# 8.851358934490344
# 8.866131976301427

# %% [markdown]
# ## E-SYN2

# %%
#Required Libraries
import numpy as np
import random
import matplotlib.pyplot as plt

a= np.random.multivariate_normal([0,0],[[0.01,0.008],[0.008,0.01]],size=1000)
z1=a[:,0]
z2=a[:,1]
freq_sample=1000
freq=100
samples=1000
noise=0.00008*np.asarray(random.sample(range(0,1000),samples))

x_input=np.arange(samples)
y_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1

for i in range(len(y_out)):
    if i <= 50:
        y_out[i]=y_out[i]+40
    
  #  if i < 50:
   #     y_out1[i]=y_out1[i]+60
    


    if i>=51 and i<=56:
        y_out[i]=y_out[i]
    
    if i>=57 and i<=100:
        y_out[i]=y_out[i]

    if i>=101 and i<=104:
        y_out[i]=y_out[i]+16
        
    if i>=110 and i<=120:
        y_out[i]=y_out[i]+16    
    if i>=121 and i<=170:
        y_out[i]=y_out[i]+16    
    if i>=171 and i<=300:
        y_out[i]=y_out[i]    
    
    if i>=301 and i<=350:
        y_out[i]=y_out[i]
        
    
    if i>=351 and i<=600:
        y_out[i]=y_out[i]+20

    
    if i>=601 and i<=620:
        y_out[i]=y_out[i]+30
    
    
    
    if i>=621 and i<=680:
        y_out[i]=y_out[i]+30
    

    if i>=700 and i<=720:
        y_out[i]=y_out[i]
    
    
    if i>=721 and i<=735:
        y_out[i]=y_out[i]
    
    if i>=737 and i<=739:
        y_out[i]=y_out[i]-19

    if i>=740 and i<=800:
        y_out[i]=y_out[i]



    if i>=801 and i<=900:
        y_out[i]=y_out[i]
     
    if i>=901 and i<=999:
        y_out[i]=y_out[i]
        
        
        

for i in range(len(y_out)):
  #  if i < 50:
   #     y_out[i]=y_out[i]+100
    
    if i <= 50:
        y_out1[i]=y_out1[i]-40
    


    if i>=51 and i<=60:
        y_out1[i]=y_out1[i]
    
    if i>=61 and i<=100:
        y_out1[i]=y_out1[i]


    if i>=101 and i<=104:
        y_out[i]=y_out[i]-16

    if i>=110 and i<=120:
        y_out1[i]=y_out1[i]-16    
    if i>=121 and i<=170:
        y_out1[i]=y_out1[i]-16    
    if i>=171 and i<=300:
        y_out1[i]=y_out1[i]    
    
    if i>=301 and i<=350:
        y_out1[i]=y_out1[i]
        
    
    if i>=351 and i<=600:
        y_out1[i]=y_out1[i]+10

    
    if i>=601 and i<=620:
        y_out1[i]=y_out1[i]-30
    
    
    
    if i>=621 and i<=680:
        y_out1[i]=y_out1[i]-30
    

    if i>=700 and i<=720:
        y_out1[i]=y_out1[i]
    
    
    if i>=721 and i<=800:
        y_out1[i]=y_out1[i]
    
    if i>=801 and i<900:
        y_out1[i]=y_out1[i]
     
    if i>=901 and i<=904:
        y_out1[i]=y_out1[i]-40
        
    if i>=986 and i<=989:
        y_out1[i]=y_out1[i]+20
        
    if i>=990 and i<=1000:
        y_out1[i]=y_out1[i]

        
print(y_out.mean())
print(y_out1.mean())  
print(y_out.std())
print(y_out1.std())


plt.figure(figsize=(8, 8))
plt.subplot(2,1,1)      
plt.plot(x_input,y_out)
plt.subplot(2,1,2)
plt.plot(x_input,y_out1)
#plt.plot(x_input,z2)
plt.show()
# Out:
# 10.361159162674157
# -2.9911007274334396
# 12.790375156031088
# 13.907147854115758

# %% [markdown]
# ## E-SYN3

# %%
#Required Libraries
import numpy as np
import random
import matplotlib.pyplot as plt

a= np.random.multivariate_normal([0,0],[[0.01,0.008],[0.008,0.01]],size=1000)
z1=a[:,0]
z2=a[:,1]
freq_sample=1000
freq=100
samples=1000
noise=0.00008*np.asarray(random.sample(range(0,1000),samples))

x_input=np.arange(samples)
y_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1



for i in range(len(y_out)):
    if i <= 50:
        y_out[i]=y_out[i]+40
    
  #  if i < 50:
   #     y_out1[i]=y_out1[i]+60
    


    if i>=51 and i<=56:
        y_out[i]=y_out[i]+20
    
    if i>=57 and i<=100:
        y_out[i]=y_out[i]+16

    if i>=101 and i<=104:
        y_out[i]=y_out[i]-16
        
    if i>=110 and i<=120:
        y_out[i]=y_out[i]-20    
    if i>=121 and i<=170:
        y_out[i]=y_out[i]+20    
    if i>=171 and i<=300:
        y_out[i]=y_out[i]-15    
    
    if i>=301 and i<=350:
        y_out[i]=y_out[i]+15
        
    
    if i>=351 and i<=600:
        y_out[i]=y_out[i]-30

    
    if i>=601 and i<=620:
        y_out[i]=y_out[i]+25
    
    
    
    if i>=620 and i<=680:
        y_out[i]=y_out[i]+0
    

    if i>=700 and i<=720:
        y_out[i]=y_out[i]-20
    
    
    if i>=721 and i<=35:
        y_out[i]=y_out[i]
    
    if i>=737 and i<=739:
        y_out[i]=y_out[i]+30

    if i>=740 and i<=800:
        y_out[i]=y_out[i]



    if i>=801 and i<=900:
        y_out[i]=y_out[i]+17
     
    if i>=901 and i<=999:
        y_out[i]=y_out[i]+15
        
        
        

        
for i in range(len(y_out)):
  #  if i < 50:
   #     y_out[i]=y_out[i]+100
    
    if i <= 50:
        y_out1[i]=y_out1[i]
    


    if i>=51 and i<=60:
        y_out1[i]=y_out1[i]
    
    if i>=61 and i<=100:
        y_out1[i]=y_out1[i]-20


    if i>=101 and i<=104:
        y_out[i]=y_out[i]+4

    if i>=110 and i<=120:
        y_out1[i]=y_out1[i]-18    
    if i>=121 and i<=170:
        y_out1[i]=y_out1[i]    
    if i>=171 and i<=300:
        y_out1[i]=y_out1[i]+20    
    
    if i>=301 and i<=350:
        y_out1[i]=y_out1[i]+16
        
    
    if i>=351 and i<=600:
        y_out1[i]=y_out1[i]+22

    
    if i>=601 and i<=620:
        y_out1[i]=y_out1[i]-12
    
    
    
    if i>=620 and i<=680:
        y_out1[i]=y_out1[i]
    

    if i>=700 and i<=720:
        y_out1[i]=y_out1[i]+20
    
    
    if i>=721 and i<=800:
        y_out1[i]=y_out1[i]-30
    
    if i>=801 and i<900:
        y_out1[i]=y_out1[i]-20
     
    if i>=901 and i<=905:
        y_out1[i]=y_out1[i]
        
    if i>=986 and i<=990:
        y_out1[i]=y_out1[i]-15
        
    if i>=991 and i<=1000:
        y_out1[i]=y_out1[i]+17

        
print(y_out.mean())
print(y_out1.mean())  
print(y_out.std())
print(y_out1.std())

plt.figure(figsize=(8, 8))
plt.subplot(2,1,1)      
plt.plot(x_input,y_out)
plt.subplot(2,1,2)
plt.plot(x_input,y_out1)
#plt.plot(x_input,z2)
plt.show()
# Out:
# -1.7490109086800898
# 3.7814696891217285
# 21.398524282009728
# 17.845316379619174

# %% [markdown]
# ## E-SYN4

# %%
#Required Libraries
import numpy as np
import random
import matplotlib.pyplot as plt

a= np.random.multivariate_normal([0,0],[[0.01,0.008],[0.008,0.01]],size=1000)
z1=a[:,0]
z2=a[:,1]
freq_sample=1000
freq=100
samples=1000
noise=0.00008*np.asarray(random.sample(range(0,1000),samples))

x_input=np.arange(samples)
y_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1


for i in range(len(y_out)):
    if i <= 50:
        y_out[i]=y_out[i]+40
    
  #  if i < 50:
   #     y_out1[i]=y_out1[i]+60
    


    if i>=51 and i<=56:
        y_out[i]=y_out[i]
    
    if i>=57 and i<=61:
        y_out[i]=y_out[i]-16

    if i>=62 and i<=100:
        y_out[i]=y_out[i]


    if i>=101 and i<=104:
        y_out[i]=y_out[i]
        
    if i>=110 and i<=120:
        y_out[i]=y_out[i]-20    
    if i>=121 and i<=140:
        y_out[i]=y_out[i]

    if i>=141 and i<=150:
        y_out[i]=y_out[i]+50    

    if i>=151 and i<=170:
        y_out[i]=y_out[i]

    if i>=171 and i<=300:
        y_out[i]=y_out[i]-15

    if i>=171 and i<=185:
        y_out[i]=y_out[i]

    if i>=186 and i<=200:
        y_out[i]=y_out[i]+25

    if i>=200 and i<=250:
        y_out[i]=y_out[i]-25

    if i>=251 and i<=296:
        y_out[i]=y_out[i]

    if i>=296 and i<=300:
        y_out[i]=y_out[i]+19

    if i>=301 and i<=320:
        y_out[i]=y_out[i]


    
    if i>=321 and i<=324:
        y_out[i]=y_out[i]+15
        
    
    if i>=321 and i<=350:
        y_out[i]=y_out[i]


    if i>=351 and i<=400:
        y_out[i]=y_out[i]

    
    if i>=401 and i<=500:
        y_out[i]=y_out[i]+20

    if i>=501 and i<=600:
        y_out[i]=y_out[i]-30  


    if i>=601 and i<=620:
        y_out[i]=y_out[i]+25
    
    
    
    if i>=620 and i<=680:
        y_out[i]=y_out[i]+0
    

    if i>=700 and i<=720:
        y_out[i]=y_out[i]-20
    
    
    if i>=721 and i<=750:
        y_out[i]=y_out[i]

    if i>=750 and i<=752:
        y_out[i]=y_out[i]+30
    
    
    if i>=753 and i<=800:
        y_out[i]=y_out[i]


    if i>=801 and i<=900:
        y_out[i]=y_out[i]

    if i>=901 and i<=903:
        y_out[i]=y_out[i]-20
     
    
    if i>=901 and i<=930:
        y_out[i]=y_out[i]
    

    if i>=931 and i<=941:
        y_out[i]=y_out[i]-50


    if i>=942 and i<=959:
        y_out[i]=y_out[i]+50
    
    
    if i>=960 and i<=1000:
        y_out[i]=y_out[i]
        
        
        

        
for i in range(len(y_out)):
  #  if i < 50:
   #     y_out[i]=y_out[i]+100
    
    if i <= 50:
        y_out1[i]=y_out1[i]-40
    


    if i>=51 and i<=60:
        y_out1[i]=y_out1[i]
    
    if i>=61 and i<=63:
        y_out1[i]=y_out1[i]-20
    
    if i>=64 and i<=100:
        y_out1[i]=y_out1[i]


    if i>=101 and i<=104:
        y_out[i]=y_out[i]

    if i>=110 and i<=120:
        y_out1[i]=y_out1[i]-18    
    if i>=121 and i<=170:
        y_out1[i]=y_out1[i]    
    if i>=171 and i<=300:
        y_out1[i]=y_out1[i]+20    
    
    if i>=301 and i<=350:
        y_out1[i]=y_out1[i]-25
        
    
    if i>=351 and i<=600:
        y_out1[i]=y_out1[i]

    
    if i>=601 and i<=620:
        y_out1[i]=y_out1[i]-12
    
    
    
    if i>=620 and i<=680:
        y_out1[i]=y_out1[i]
    

    if i>=700 and i<=720:
        y_out1[i]=y_out1[i]+20
    
    
    if i>=721 and i<=800:
        y_out1[i]=y_out1[i]-30
    
    if i>=801 and i<=896:
        y_out1[i]=y_out1[i]

    if i>=897 and i<=900:
        y_out1[i]=y_out1[i]+20
     
    if i>=901 and i<=905:
        y_out1[i]=y_out1[i]


    if i>=906 and i<=950:
        y_out1[i]=y_out1[i]+35


    if i>=951 and i<=971:
        y_out1[i]=y_out1[i]-45





        
    if i>=986 and i<=990:
        y_out1[i]=y_out1[i]-15
        
    if i>=991 and i<=994:
        y_out1[i]=y_out1[i]
    
    if i>=991 and i<=994:
        y_out1[i]=y_out1[i]


    if i>=995 and i<=980:
        y_out1[i]=y_out1[i]-50

    
    
    if i>=981 and i<=1000:
        y_out1[i]=y_out1[i]




        
print(y_out.mean())
print(y_out1.mean())  
print(y_out.std())
print(y_out1.std())

        
plt.plot(x_input,y_out)
plt.show()
plt.plot(x_input,y_out1)
#plt.plot(x_input,z2)
plt.show()
# Out:
# -0.9967021253719729
# -2.5348756471762397
# 20.853040024450454
# 18.626590119681484
