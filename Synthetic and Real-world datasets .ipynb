# %% [markdown]
# # DATASETS PREPARATION

# %% [markdown]
# # Syntheic Datasets SYN* for Evaluating the performance and accuracy of the Algorithm - DDMTS, OD and AD

# %% [markdown]
# ## SYN1

# %%
#Required Libraries
import numpy as np
import random
import matplotlib.pyplot as plt

a= np.random.multivariate_normal([0,0],[[0.01,0.008],[0.008,0.01]],size=1000)
z1=a[:,0]
z2=a[:,1]
freq_sample=1000
freq=100
samples=1000
noise=0.00008*np.asarray(random.sample(range(0,1000),samples))

x_input=np.arange(samples)
y_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1

#series 1
for i in range(len(y_out)):
    if i <= 100:
        y_out[i]=y_out[i]+40
    if i>=101 and i<=700:
        y_out[i]=y_out[i]+5
    
    if i>=701 and i<=703:
        y_out[i]=y_out[i]+50

    if i>=704 and i<=1000:
        y_out[i]=y_out[i]+5

#series 2        
        
for i in range(len(y_out)):
    if i <= 100:
        y_out1[i]=y_out1[i]-40
    if i>=101 and i<=300:
        y_out1[i]=y_out1[i]+10
    if i>=301 and i<=330:
        y_out1[i]=y_out1[i]-20
    if i>=331 and i<=1000:
        y_out1[i]=y_out1[i]+10
        
#series 3        
for i in range(len(y_out2)):
    if i <= 100:
        y_out2[i]=y_out2[i]-70
    if i>=101 and i<=300:
        y_out2[i]=y_out2[i]+5
    if i>=301 and i<=330:
        y_out2[i]=y_out2[i]+5
    if i>=331 and i<=1000:
        y_out2[i]=y_out2[i]+5
        
        
#series 5
for i in range(len(y_out)):
    if i <= 100:
        y_out3[i]=y_out3[i]+70
    if i>=101 and i<=700:
        y_out3[i]=y_out3[i]+10
    
    if i>=701 and i<=703:
        y_out3[i]=y_out3[i]+10

    if i>=704 and i<=800:
        y_out3[i]=y_out3[i]+10
        
    if i>=801 and i<=803:
        y_out3[i]=y_out3[i]-30
    
    if i>=804 and i<=1000:
        y_out3[i]=y_out3[i]+10

# %%
plt.figure(figsize=(8, 8))

plt.subplot(2,1,1)
plt.plot(x_input,y_out)
plt.ylim(-50,60)
plt.xticks([0,200,400,600,800,1000],size=20)
#plt.xlabel("time")
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 1",size=20)
#plt.legend("Ser")

plt.subplot(2,1,2)
plt.plot(x_input,y_out1,c="red")
plt.xticks([0,200,400,600,800,1000],size=20)
plt.ylim(-50,60)
plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 2",size=20)
#plt.legend("Series 2")

#plt.subplot(4,1,3)

#plt.plot(x_input,y_out2,c="orange")
#plt.ylim(-80,60)
#plt.xticks([0,200,400,600,800,1000],size=12)

#plt.yticks([-50,0,50],size=12)
#plt.xlabel("time", size=12)
#plt.ylabel("Series 3",size=12)



#plt.subplot(4,1,4)

#plt.plot(x_input,y_out3,c ="green")
#plt.ylim(-50,100)
#plt.xticks([0,200,400,600,800,1000],size=12)

#plt.yticks([-50,0,50],size=12)
#plt.xlabel("time", size=12)
#plt.ylabel("Series 4",size=12)
# Out:
# Text(0, 0.5, 'Series 2')

# %% [markdown]
# ## SYN2

# %%
y2_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y2_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y2_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y2_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y2_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1


#series 1
for i in range(len(y_out)):
    if i <= 349:
        y2_out[i]=y2_out[i]+5
    if i>=350 and i<=500:
        y2_out[i]=y2_out[i]+45
        
    if i>=501 and i<=700:
        y2_out[i]=y2_out[i]+5
    
    if i>=701 and i<=800:
        y2_out[i]=y2_out[i]-50

    if i>=801 and i<=1000:
        y2_out[i]=y2_out[i]+5

#series 2        
        
for i in range(len(y_out)):
    if i <= 399:
        y2_out1[i]=y2_out1[i]+10
    if i>=400 and i<=500:
        y2_out1[i]=y2_out1[i]-45
    if i>=501 and i<=700:
        y2_out1[i]=y2_out1[i]+10
    if i>=701 and i<=800:
        y2_out1[i]=y2_out1[i]-30
    if i>=801 and i<=1000:
        y2_out1[i]=y2_out1[i]+10
        
        
#series 3        
for i in range(len(y_out2)):
    if i >= 0 and i<=200 :
        y2_out2[i]=y2_out2[i]+5    
    if i >= 201 and i<=203 :
        y2_out2[i]=y2_out2[i]-60
    if i >= 204 and i<=399 :
        y2_out2[i]=y2_out2[i]+5
    if i>=400 and i<=500:
        y2_out2[i]=y2_out2[i]-55
    if i>=501 and i<=700:
        y2_out2[i]=y2_out2[i]+5
    if i>=701 and i<=800:
        y2_out2[i]=y2_out2[i]+30
    if i>=801 and i<=1000:
        y2_out2[i]=y2_out2[i]+5
        
        
#series 4
for i in range(len(y_out)):
    if i <= 399:
        y2_out3[i]=y2_out3[i]+5
    if i>=400 and i<=500:
        y2_out3[i]=y2_out3[i]+45
        
    if i>=501 and i<=700:
        y2_out3[i]=y2_out3[i]+5
    
    if i>=701 and i<=800:
        y2_out3[i]=y2_out3[i]-50

    if i>=801 and i<=850:
        y2_out3[i]=y2_out3[i]+5
    
    if i>=851 and i<=853:
        y2_out3[i]=y2_out3[i]+50
    
    if i>=854 and i<=1000:
        y2_out3[i]=y2_out3[i]+5

# %%
plt.figure(figsize=(8, 8))

plt.subplot(2,1,1)
plt.plot(x_input,y2_out)
plt.ylim(-70,70)

plt.xticks([0,200,400,600,800,1000],size=20)

plt.yticks([-50,0,50],size=20)
#plt.xlabel("time", size=20)
plt.ylabel("Series 1",size=20)


plt.subplot(2,1,2)
plt.plot(x_input,y2_out1,c="red")
plt.ylim(-50,60)
plt.xticks([0,200,400,600,800,1000],size=20)

plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 2",size=20)


#plt.subplot(4,1,3)
#plt.plot(x_input,y2_out2,c="orange")
#plt.ylim(-80,70)
#plt.xticks([0,200,400,600,800,1000],size=12)

#plt.yticks([-50,0,50],size=12)
#plt.xlabel("time", size=12)
#plt.ylabel("Series 3",size=12)



#plt.subplot(4,1,4)

#plt.plot(x_input,y2_out3,c ="green")
#plt.ylim(-70,100)
#plt.xlabel("time")

#plt.xticks([0,200,400,600,800,1000],size=12)

#plt.yticks([-50,0,50],size=12)
#plt.xlabel("time", size=12)
#plt.ylabel("Series 4",size=12)



#plt.plot(x_input,y_out4)
# Out:
# Text(0, 0.5, 'Series 2')

# %% [markdown]
# ## SYN3

# %%
x_input=np.arange(samples)
y3_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y3_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y3_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y3_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y3_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1

#series 1
for i in range(len(y_out)):
    if i < 50:
        y3_out[i]=y3_out[i]+5
    if i >= 50 and i<= 100:
        y3_out[i]=y3_out[i]+40
    if i>=101 and i<=300:
        y3_out[i]=y3_out[i]+5
    if i>=301 and i<=400:
        y3_out[i]=y3_out[i]-30
    if i>=401 and i<=700:
        y3_out[i]=y3_out[i]+5
    
    if i>=701 and i<=703:
        y3_out[i]=y3_out[i]+70

    if i>=704 and i<=850:
        y3_out[i]=y3_out[i]+5
    if i>=851 and i<=852:
        y3_out[i]=y3_out[i]-50
    if i>=853 and i<=1000:
        y3_out[i]=y3_out[i]+5

        

#series 2        
        
for i in range(len(y_out)):
    if i <= 50:
        y3_out1[i]=y3_out1[i]+10
    
    if i > 50 and i<= 100:
        y3_out1[i]=y3_out1[i]-40
    if i>=101 and i<=300:
        y3_out1[i]=y3_out1[i]+10
    if i>=301 and i<=330:
        y3_out1[i]=y3_out1[i]-20
    if i>=331 and i<=1000:
        y3_out1[i]=y3_out1[i]+10
        
#series 3        
for i in range(len(y_out)):
    if i < 51: 
        y3_out2[i]=y3_out2[i]+5
    if i > 51 and i<=100:
        y3_out2[i]=y3_out2[i]-45
    if i>=101 and i<=300:
        y3_out2[i]=y3_out2[i]+5
    if i>=301 and i<=400:
        y3_out2[i]=y3_out2[i]-30
    if i>=401 and i<=780:
        y3_out2[i]=y3_out2[i]+5
    
    if i>=781 and i<=783:
        y3_out2[i]=y3_out2[i]+50

    if i>=784 and i<=850:
        y3_out2[i]=y3_out2[i]+5
    if i>=851 and i<=852:
        y3_out2[i]=y3_out2[i]+5
    if i>=853 and i<=1000:
        y3_out2[i]=y3_out2[i]+5

        
#series 4
for i in range(len(y_out)):
    if i<=51:
        y3_out3[i]=y3_out3[i]+5
        
    if i > 50 and i<=100:
        y3_out3[i]=y3_out3[i]-45
    if i>=101 and i<=300:
        y3_out3[i]=y3_out3[i]+5
    if i>=301 and i<=400:
        y3_out3[i]=y3_out3[i]-30
    if i>=401 and i<=780:
        y3_out3[i]=y3_out3[i]+5
    
    if i>=781 and i<=783:
        y3_out3[i]=y3_out3[i]+5

        
    if i>=784 and i<=850:
        y3_out3[i]=y3_out3[i]+5
    if i>=851 and i<=852:
        y3_out3[i]=y3_out3[i]+5
    if i>=853 and i<=1000:
        y3_out3[i]=y3_out3[i]+5

# %%
plt.figure(figsize=(8, 8))

plt.subplot(2,1,1)
plt.plot(x_input,y3_out)
plt.ylim(-70,90)

plt.xticks([0,200,400,600,800,1000],size=20)
#plt.xlabel("time")
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 1",size=20)

plt.subplot(2,1,2)
plt.plot(x_input,y3_out1,c="red")
plt.ylim(-50,60)

plt.xticks([0,200,400,600,800,1000],size=20)
plt.xlabel("time",size=20)
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 2",size=20)

#plt.subplot(4,1,3)
#plt.plot(x_input,y3_out2,c="orange")
#plt.ylim(-80,60)
#plt.xticks([0,200,400,600,800,1000],size=12)
#plt.xlabel("time",size=12)
#plt.yticks([-50,0,50],size=12)
#plt.ylabel("Series 3",size=12)

#plt.subplot(4,1,4)

#plt.plot(x_input,y3_out3,c ="green")
#plt.ylim(-70,100)
#plt.xticks([0,200,400,600,800,1000],size=12)
#plt.xlabel("time",size=12)
#plt.yticks([-50,0,50],size=12)
#plt.ylabel("Series 4",size=12)
# Out:
# Text(0, 0.5, 'Series 2')

# %% [markdown]
# # Injecting artifical deviations in the real-world data set to check the accuracy and performance of the DDMTS, OD and AD
#
# The dataset is available at
# Beach Water Quality - Automated Sensors | City of Chicago | Data Portal. The sensor
# locations are listed at https://data.cityofchicago.org/d/g3ip-u8rb.

# %% [markdown]
# ## importing real world data from

# %%
import pandas as pd 
dataset = pd.read_csv('rwd.csv')
X = dataset.iloc[:, [0, 1, 2,3,4,5,6]].values

# %% [markdown]
# ## RWD1

# %%
for i in range(len(X[:,3])):
    if i <= 100:
        X[:,3][i]=X[:,3][i]-20
    if i>=101 and i<=300:
        X[:,3][i]=X[:,3][i]
    if i>=301 and i<=400:
        X[:,3][i]=X[:,3][i]-40
    if i>=401 and i<=780:
        X[:,3][i]=X[:,3][i]
    if i>=501 and i<=503:
        X[:,3][i]=X[:,3][i]-60  
    if i>=600 and i<=650:
        X[:,3][i]=X[:,3][i]+40      
    if i>=784 and i<=850:
        X[:,3][i]=X[:,3][i]+30
    if i>=851 and i<=852:
        X[:,3][i]=X[:,3][i]
    if i>=853 and i<=1000:
        X[:,3][i]=X[:,3][i]
    if i>=1400 and i<=1403:
        X[:,3][i]=X[:,3][i]+40

# %%
for i in range(len(X[:,0])):
    if i <= 100:
        X[:,0][i]=X[:,0][i]-30
    if i>=101 and i<=300:
        X[:,0][i]=X[:,0][i]
    if i>=301 and i<=400:
        X[:,0][i]=X[:,0][i]+30
    if i>=401 and i<=500:
        X[:,0][i]=X[:,0][i]
    
    
    
    if i>=401 and i<=780:
        X[:,0][i]=X[:,0][i]
    if i>=781 and i<=783:
        X[:,0][i]=X[:,0][i]

        
    if i>=784 and i<=850:
        X[:,0][i]=X[:,0][i]-30
    if i>=851 and i<=852:
        X[:,0][i]=X[:,0][i]
    if i>=853 and i<=1000:
        X[:,0][i]=X[:,0][i]
    if i>=1030 and i<=1033:
        X[:,0][i]=X[:,0][i]+50


for i in range(len(X[:,1])):
    if i <= 100:
        X[:,1][i]=X[:,1][i]+30
    if i>=101 and i<=300:
        X[:,1][i]=X[:,1][i]
    if i>=301 and i<=400:
        X[:,1][i]=X[:,1][i]-40
    if i>=401 and i<=780:
        X[:,1][i]=X[:,1][i]
    if i>=501 and i<=503:
        X[:,1][i]=X[:,1][i]
   

        
    if i>=784 and i<=850:
        X[:,1][i]=X[:,1][i]+30
    if i>=851 and i<=852:
        X[:,1][i]=X[:,1][i]
    if i>=853 and i<=1000:
        X[:,1][i]=X[:,1][i]
    if i>=1001 and i<=1003:
        X[:,1][i]=X[:,1][i]+50
        
plt.figure(figsize=(8, 8))       
        
plt.subplot(2,1,1)
plt.plot(X[:,0])

plt.ylim(-100,100)
#plt.xlabel("time")
plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([-100,0,100],size=20)
plt.ylabel("AT",size=20)


plt.subplot(2,1,2)
plt.plot(X[:,1])
plt.ylim(-100,100)
plt.xlabel("time")
plt.ylabel("H")


plt.xlabel("time",size=20)

plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([-100,0,100],size=20)
plt.ylabel("H",size=20)
# Out:
# Text(0, 0.5, 'H')

# %% [markdown]
# ## RWD2

# %%
for i in range(len(X[:,5])):
    if i <= 100:
        X[:,5][i]=X[:,5][i]+25
    if i>=101 and i<=300:
        X[:,5][i]=X[:,5][i]
    if i>=301 and i<=400:
        X[:,5][i]=X[:,5][i]-20
    if i>=401 and i<=500:
        X[:,5][i]=X[:,5][i]
        
    if i>=501 and i<=503:
        X[:,5][i]=X[:,5][i]    
    
    if i>=601 and i<=603:
        X[:,5][i]=X[:,5][i]
    
    if i>=401 and i<=780:
        X[:,5][i]=X[:,5][i]
    if i>=781 and i<=783:
        X[:,5][i]=X[:,5][i]

        
    if i>=784 and i<=850:
        X[:,5][i]=X[:,5][i]-30
    if i>=851 and i<=852:
        X[:,5][i]=X[:,5][i]
    if i>=853 and i<=1000:
        X[:,5][i]=X[:,5][i]
    if i>=1001 and i<=1003:
        X[:,5][i]=X[:,5][i]+50

b=X[:,0]
print((len(X[:,0])))
print(b.std())
print(b.max())
print(b.min())




for i in range(len(X[:,3])):
    if i <= 100:
        X[:,3][i]=X[:,3][i]-20
    if i>=101 and i<=300:
        X[:,3][i]=X[:,3][i]
    if i>=301 and i<=400:
        X[:,3][i]=X[:,3][i]-40
    if i>=401 and i<=780:
        X[:,3][i]=X[:,3][i]
    if i>=501 and i<=503:
        X[:,3][i]=X[:,3][i]-60  
    if i>=600 and i<=650:
        X[:,3][i]=X[:,3][i]+40      
    if i>=784 and i<=850:
        X[:,3][i]=X[:,3][i]+30
    if i>=851 and i<=852:
        X[:,3][i]=X[:,3][i]
    if i>=853 and i<=1000:
        X[:,3][i]=X[:,3][i]
    if i>=1400 and i<=1403:
        X[:,3][i]=X[:,3][i]+40
# Out:
# 1595
# nan
# nan
# nan

# %%
plt.figure(figsize=(8, 8))       
        
plt.subplot(2,1,1)
plt.plot(X[:,3])
plt.ylim(800,1000)
#plt.xlabel("time")
plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([800,900,1000],size=20)
plt.ylabel("P",size=20)


plt.subplot(2,1,2)
plt.plot(X[:,5])
plt.ylim(-100,100)
plt.xlabel("time")



plt.xlabel("time",size=20)

plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([-50,0,50],size=20)
plt.ylabel("WS",size=20)







#plt.subplot(2,1,1)
#plt.plot(X[:,3])
#plt.ylim(800,1000)
#plt.xlabel("time")
#plt.ylabel("P")


#plt.subplot(2,1,2)
#plt.plot(X[:,5])
#plt.ylim(-80,80)
#plt.xlabel("time")
#plt.ylabel("WS")
# Out:
# Text(0, 0.5, 'WS')

# %% [markdown]
# ## RWD3

# %%
for i in range(len(X[:,5])):
    if i <= 100:
        X[:,5][i]=X[:,5][i]+25
    if i>=101 and i<=300:
        X[:,5][i]=X[:,5][i]
    if i>=301 and i<=400:
        X[:,5][i]=X[:,5][i]-20
    if i>=401 and i<=500:
        X[:,5][i]=X[:,5][i]
        
    if i>=501 and i<=503:
        X[:,5][i]=X[:,5][i]-30    
    
    if i>=601 and i<=603:
        X[:,5][i]=X[:,5][i]
    
    if i>=401 and i<=780:
        X[:,5][i]=X[:,5][i]
    if i>=781 and i<=783:
        X[:,5][i]=X[:,5][i]

        
    if i>=784 and i<=850:
        X[:,5][i]=X[:,5][i]-50
    if i>=851 and i<=852:
        X[:,5][i]=X[:,5][i]
    if i>=853 and i<=1000:
        X[:,5][i]=X[:,5][i]
    if i>=1001 and i<=1003:
        X[:,5][i]=X[:,5][i]+50



for i in range(len(X[:,6])):
    if i <= 100:
        X[:,6][i]=X[:,6][i]+20
    if i>=101 and i<=300:
        X[:,6][i]=X[:,6][i]
    if i>=301 and i<=400:
        X[:,6][i]=X[:,6][i]-20
    if i>=401 and i<=780:
        X[:,6][i]=X[:,6][i]
    
    if i>=781 and i<=783:
        X[:,6][i]=X[:,6][i]-40

        
    if i>=784 and i<=850:
        X[:,6][i]=X[:,6][i]-60
    if i>=851 and i<=852:
        X[:,6][i]=X[:,6][i]
    if i>=853 and i<=1000:
        X[:,6][i]=X[:,6][i]
    if i>=1001 and i<=1003:
        X[:,6][i]=X[:,6][i]
# Out:
# 22.59735565856146

# %%
plt.figure(figsize=(8, 8))       
        
plt.subplot(2,1,1)
plt.plot(X[:,5])
plt.ylim(-80,70)
#plt.xlabel("time")
plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([-50,0,50],size=20)
plt.ylabel("WS",size=20)


plt.subplot(2,1,2)
plt.plot(X[:,6])
plt.ylim(-60,50)




plt.xlabel("time",size=20)

plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([-80,0,50],size=20)
plt.ylabel("WH",size=20)







#plt.subplot(2,1,1)
#lt.plot(X[:,5])
#X[:,5].std()

#plt.ylim(-90,90)
#plt.xlabel("time")
#plt.ylabel("WS")



#plt.subplot(2,1,2)
#plt.plot(X[:,6])
#plt.ylim(-90,90)
#plt.xlabel("time")
#plt.ylabel("WH")
#X[:,5].std()
#len(X[:,5])
#A=X[:,5]
#A[1:1592].std()
# Out:
# Text(0, 0.5, 'WH')

# %% [markdown]
# ## RWD4

# %%
for i in range(len(X[:,0])):
    if i <= 100:
        X[:,0][i]=X[:,0][i]-25
    if i>=101 and i<=300:
        X[:,0][i]=X[:,0][i]
    if i>=301 and i<=400:
        X[:,0][i]=X[:,0][i]+20
    if i>=401 and i<=500:
        X[:,0][i]=X[:,0][i]
    
    
    
    if i>=401 and i<=780:
        X[:,0][i]=X[:,0][i]
    if i>=781 and i<=783:
        X[:,0][i]=X[:,0][i]

        
    if i>=784 and i<=850:
        X[:,0][i]=X[:,0][i]+55
    if i>=851 and i<=852:
        X[:,0][i]=X[:,0][i]
    if i>=853 and i<=1000:
        X[:,0][i]=X[:,0][i]
    if i>=1030 and i<=1033:
        X[:,0][i]=X[:,0][i]+50



#plt.subplot(2,1,1)
#plt.plot(X[:,0])


#plt.ylim(-30,100)
#plt.xlabel("time")
#plt.ylabel("AT")

for i in range(len(X[:,2])):
    if i <= 100:
        X[:,2][i]=X[:,2][i]-20
    if i>=101 and i<=300:
        X[:,2][i]=X[:,2][i]
    if i>=301 and i<=400:
        X[:,2][i]=X[:,2][i]+30
    if i>=401 and i<=780:
        X[:,2][i]=X[:,2][i]
    if i>=501 and i<=503:
        X[:,2][i]=X[:,2][i]-30
   

        
    if i>=784 and i<=850:
        X[:,2][i]=X[:,2][i]+65
    if i>=851 and i<=852:
        X[:,2][i]=X[:,2][i]
    if i>=853 and i<=1000:
        X[:,2][i]=X[:,2][i]
    if i>=1001 and i<=1003:
        X[:,2][i]=X[:,2][i]

#plt.subplot(2,1,2)
##plt.plot(X[:,2])
#plt.ylim(-30,100)
#plt.xlabel("time")
#plt.ylabel("WT")


plt.figure(figsize=(8, 8))       
        
plt.subplot(2,1,1)
plt.plot(X[:,0])
plt.ylim(-20,100)
#plt.xlabel("time")
plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([0,50,100],size=20)
plt.ylabel("AT",size=20)


plt.subplot(2,1,2)
plt.plot(X[:,2])
plt.ylim(-20,100)
#plt.xlabel("time")



plt.xlabel("time",size=20)

plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([0,50,100],size=20)
plt.ylabel("WT",size=20)
# Out:
# Text(0, 0.5, 'WT')

# %%
plt.subplot(7,1,1)

plt.plot(X[:,0])
plt.ylim(-20,100)
plt.xlabel("time")
plt.ylabel("AT")

for i in range(len(X[:,3])):
    if i <= 100:
        X[:,3][i]=X[:,3][i]-20
    if i>=101 and i<=300:
        X[:,3][i]=X[:,3][i]
    if i>=301 and i<=400:
        X[:,3][i]=X[:,3][i]-40
    if i>=401 and i<=780:
        X[:,3][i]=X[:,3][i]
    if i>=501 and i<=503:
        X[:,3][i]=X[:,3][i]  
    if i>=600 and i<=650:
        X[:,3][i]=X[:,3][i]+40      
    if i>=784 and i<=850:
        X[:,3][i]=X[:,3][i]+30
    if i>=851 and i<=852:
        X[:,3][i]=X[:,3][i]
    if i>=853 and i<=1000:
        X[:,3][i]=X[:,3][i]
    if i>=1400 and i<=1403:
        X[:,3][i]=X[:,3][i]+40




plt.subplot(7,1,3)
plt.plot(X[:,3])
plt.xlabel("time")
plt.ylabel("P")
plt.subplot(7,1,5)
plt.plot(X[:,2])
plt.ylim(-20,100)
plt.xlabel("time")
plt.ylabel("WT")
plt.subplot(7,1,7)
plt.plot(X[:,5])
plt.ylim(-40,100)
plt.xlabel("time")
plt.ylabel("WS")
# Out:
# Text(0, 0.5, 'WS')

# %% [markdown]
# ## Preparation of Modified datasets for the Anomaly Detection

# %% [markdown]
# ## M-SYN1

# %%
#Required Libraries
import numpy as np
import random
import matplotlib.pyplot as plt

a= np.random.multivariate_normal([0,0],[[0.01,0.008],[0.008,0.01]],size=1000)
z1=a[:,0]
z2=a[:,1]
freq_sample=1000
freq=100
samples=1000
noise=0.00008*np.asarray(random.sample(range(0,1000),samples))

x_input=np.arange(samples)
y_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1

#series 1
for i in range(len(y_out)):
    if i <= 100:
        y_out[i]=y_out[i]+40
    if i>=101 and i<=700:
        y_out[i]=y_out[i]+5
    
    if i>=701 and i<=703:
        y_out[i]=y_out[i]+50

    if i>=704 and i<=1000:
        y_out[i]=y_out[i]+5

#series 2        
        
for i in range(len(y_out)):
    if i <= 100:
        y_out1[i]=y_out1[i]-40
    if i>=101 and i<=300:
        y_out1[i]=y_out1[i]+10
    if i>=301 and i<=330:
        y_out1[i]=y_out1[i]-20
    if i>=331 and i<=1000:
        y_out1[i]=y_out1[i]+10
        
#series 3        
for i in range(len(y_out2)):
    if i <= 100:
        y_out2[i]=y_out2[i]-70
    if i>=101 and i<=300:
        y_out2[i]=y_out2[i]+5
    if i>=301 and i<=330:
        y_out2[i]=y_out2[i]+5
    if i>=331 and i<=1000:
        y_out2[i]=y_out2[i]+5
        
        
#series 5
for i in range(len(y_out)):
    if i <= 100:
        y_out3[i]=y_out3[i]+70
    if i>=101 and i<=700:
        y_out3[i]=y_out3[i]+10
    
    if i>=701 and i<=703:
        y_out3[i]=y_out3[i]+10

    if i>=704 and i<=800:
        y_out3[i]=y_out3[i]+10
        
    if i>=801 and i<=803:
        y_out3[i]=y_out3[i]-30
    
    if i>=804 and i<=1000:
        y_out3[i]=y_out3[i]+10

# %%
plt.figure(figsize=(8, 8))

plt.subplot(7,1,1)
plt.plot(x_input,y_out)
plt.ylim(-50,60)
plt.xticks([0,200,400,600,800,1000],size=20)
#plt.xlabel("time")
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 1",size=20)
#plt.legend("Ser")

plt.subplot(7,1,3)
plt.plot(x_input,y_out1,c="red")
plt.xticks([0,200,400,600,800,1000],size=20)
plt.ylim(-50,60)
plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 2",size=20)
plt.legend("Series 2")

plt.subplot(7,1,5)

plt.plot(x_input,y_out2,c="orange")
plt.ylim(-80,60)
plt.xticks([0,200,400,600,800,1000],size=12)

plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 3",size=20)



plt.subplot(7,1,7)

plt.plot(x_input,y_out3,c ="green")
plt.ylim(-50,100)
plt.xticks([0,200,400,600,800,1000],size=20)

plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 4",size=20)
# Out:
# Text(0, 0.5, 'Series 4')

# %% [markdown]
# ## M-SYN2

# %%
y2_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y2_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y2_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y2_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y2_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1


#series 1
for i in range(len(y_out)):
    if i <= 349:
        y2_out[i]=y2_out[i]+5
    if i>=350 and i<=500:
        y2_out[i]=y2_out[i]+45
        
    if i>=501 and i<=700:
        y2_out[i]=y2_out[i]+5
    
    if i>=701 and i<=800:
        y2_out[i]=y2_out[i]-50

    if i>=801 and i<=1000:
        y2_out[i]=y2_out[i]+5

#series 2        
        
for i in range(len(y_out)):
    if i <= 399:
        y2_out1[i]=y2_out1[i]+10
    if i>=400 and i<=500:
        y2_out1[i]=y2_out1[i]-45
    if i>=501 and i<=700:
        y2_out1[i]=y2_out1[i]+10
    if i>=701 and i<=800:
        y2_out1[i]=y2_out1[i]-30
    if i>=801 and i<=1000:
        y2_out1[i]=y2_out1[i]+10
        
        
#series 3        
for i in range(len(y_out2)):
    if i >= 0 and i<=200 :
        y2_out2[i]=y2_out2[i]+5    
    if i >= 201 and i<=203 :
        y2_out2[i]=y2_out2[i]-60
    if i >= 204 and i<=399 :
        y2_out2[i]=y2_out2[i]+5
    if i>=400 and i<=500:
        y2_out2[i]=y2_out2[i]-55
    if i>=501 and i<=700:
        y2_out2[i]=y2_out2[i]+5
    if i>=701 and i<=800:
        y2_out2[i]=y2_out2[i]+30
    if i>=801 and i<=1000:
        y2_out2[i]=y2_out2[i]+5
        
        
#series 4
for i in range(len(y_out)):
    if i <= 399:
        y2_out3[i]=y2_out3[i]+5
    if i>=400 and i<=500:
        y2_out3[i]=y2_out3[i]+45
        
    if i>=501 and i<=700:
        y2_out3[i]=y2_out3[i]+5
    
    if i>=701 and i<=800:
        y2_out3[i]=y2_out3[i]-50

    if i>=801 and i<=850:
        y2_out3[i]=y2_out3[i]+5
    
    if i>=851 and i<=853:
        y2_out3[i]=y2_out3[i]+50
    
    if i>=854 and i<=1000:
        y2_out3[i]=y2_out3[i]+5

# %%
plt.figure(figsize=(8, 8))

plt.subplot(7,1,1)
plt.plot(x_input,y2_out)
plt.ylim(-70,70)

plt.xticks([0,200,400,600,800,1000],size=20)

plt.yticks([-50,0,50],size=20)
#plt.xlabel("time", size=20)
plt.ylabel("Series 1",size=20)


plt.subplot(7,1,3)
plt.plot(x_input,y2_out1,c="red")
plt.ylim(-50,60)
plt.xticks([0,200,400,600,800,1000],size=20)

plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 2",size=20)


plt.subplot(7,1,5)
plt.plot(x_input,y2_out2,c="orange")
plt.ylim(-80,70)
plt.xticks([0,200,400,600,800,1000],size=20)

plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 3",size=20)



plt.subplot(7,1,7)

plt.plot(x_input,y2_out3,c ="green")
plt.ylim(-70,100)
plt.xlabel("time")

plt.xticks([0,200,400,600,800,1000],size=20)

plt.yticks([-50,0,50],size=20)
plt.xlabel("time", size=20)
plt.ylabel("Series 4",size=20)



#plt.plot(x_input,y_out4)
# Out:
# Text(0, 0.5, 'Series 4')

# %% [markdown]
# ## M-SYN3

# %%
x_input=np.arange(samples)
y3_out=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y3_out1=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y3_out2=(np.sin(2*np.pi*freq*x_input/freq_sample))+z2
y3_out3=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1
y3_out4=(np.sin(2*np.pi*freq*x_input/freq_sample))+z1

#series 1
for i in range(len(y_out)):
    if i < 50:
        y3_out[i]=y3_out[i]+5
    if i >= 50 and i<= 100:
        y3_out[i]=y3_out[i]+40
    if i>=101 and i<=300:
        y3_out[i]=y3_out[i]+5
    if i>=301 and i<=400:
        y3_out[i]=y3_out[i]-30
    if i>=401 and i<=700:
        y3_out[i]=y3_out[i]+5
    
    if i>=701 and i<=703:
        y3_out[i]=y3_out[i]+70

    if i>=704 and i<=850:
        y3_out[i]=y3_out[i]+5
    if i>=851 and i<=852:
        y3_out[i]=y3_out[i]-50
    if i>=853 and i<=1000:
        y3_out[i]=y3_out[i]+5

        

#series 2        
        
for i in range(len(y_out)):
    if i <= 50:
        y3_out1[i]=y3_out1[i]+10
    
    if i > 50 and i<= 100:
        y3_out1[i]=y3_out1[i]-40
    if i>=101 and i<=300:
        y3_out1[i]=y3_out1[i]+10
    if i>=301 and i<=330:
        y3_out1[i]=y3_out1[i]-20
    if i>=331 and i<=1000:
        y3_out1[i]=y3_out1[i]+10
        
#series 3        
for i in range(len(y_out)):
    if i < 51: 
        y3_out2[i]=y3_out2[i]+5
    if i > 51 and i<=100:
        y3_out2[i]=y3_out2[i]-45
    if i>=101 and i<=300:
        y3_out2[i]=y3_out2[i]+5
    if i>=301 and i<=400:
        y3_out2[i]=y3_out2[i]-30
    if i>=401 and i<=780:
        y3_out2[i]=y3_out2[i]+5
    
    if i>=781 and i<=783:
        y3_out2[i]=y3_out2[i]+50

    if i>=784 and i<=850:
        y3_out2[i]=y3_out2[i]+5
    if i>=851 and i<=852:
        y3_out2[i]=y3_out2[i]+5
    if i>=853 and i<=1000:
        y3_out2[i]=y3_out2[i]+5

        
#series 4
for i in range(len(y_out)):
    if i<=51:
        y3_out3[i]=y3_out3[i]+5
        
    if i > 50 and i<=100:
        y3_out3[i]=y3_out3[i]-45
    if i>=101 and i<=300:
        y3_out3[i]=y3_out3[i]+5
    if i>=301 and i<=400:
        y3_out3[i]=y3_out3[i]-30
    if i>=401 and i<=780:
        y3_out3[i]=y3_out3[i]+5
    
    if i>=781 and i<=783:
        y3_out3[i]=y3_out3[i]+5

        
    if i>=784 and i<=850:
        y3_out3[i]=y3_out3[i]+5
    if i>=851 and i<=852:
        y3_out3[i]=y3_out3[i]+5
    if i>=853 and i<=1000:
        y3_out3[i]=y3_out3[i]+5

# %%
plt.figure(figsize=(8, 8))

plt.subplot(7,1,1)
plt.plot(x_input,y3_out)
plt.ylim(-70,90)

plt.xticks([0,200,400,600,800,1000],size=20)
#plt.xlabel("time")
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 1",size=20)

plt.subplot(7,1,3)
plt.plot(x_input,y3_out1,c="red")
plt.ylim(-50,60)

plt.xticks([0,200,400,600,800,1000],size=20)
plt.xlabel("time",size=20)
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 2",size=20)

plt.subplot(7,1,5)
plt.plot(x_input,y3_out2,c="orange")
plt.ylim(-80,60)
plt.xticks([0,200,400,600,800,1000],size=20)
plt.xlabel("time",size=20)
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 3",size=20)

plt.subplot(7,1,7)

plt.plot(x_input,y3_out3,c ="green")
plt.ylim(-70,100)
plt.xticks([0,200,400,600,800,1000],size=20)
plt.xlabel("time",size=20)
plt.yticks([-50,0,50],size=20)
plt.ylabel("Series 4",size=20)
# Out:
# Text(0, 0.5, 'Series 4')

# %% [markdown]
# # Modified Real-world dataset (M-RWD*)

# %% [markdown]
# ## MRWD2

# %%
plt.figure(figsize=(8, 8))       
        
plt.subplot(7,1,1)
plt.plot(X[:,3])
plt.ylim(850,1000)
#plt.xlabel("time")
plt.xticks([0,400,800,1200,1600],size=20)
plt.yticks([800,900,1000],size=20)
plt.ylabel("P",size=20)


plt.subplot(7,1,3)
plt.plot(X[:,5])
plt.ylim(-60,70)
plt.yticks([-50,0,50],size=20)
plt.xticks([0,400,800,1200,1600],size=20)
plt.ylabel("WS",size=20)
#plt.xlabel("time")


plt.subplot(7,1,5)
plt.plot(X[:,0])
plt.ylim(-20,100)
plt.yticks([0,50,100],size=20)
plt.xticks([0,400,800,1200,1600],size=20)
plt.ylabel("AT",size=20)
#plt.xlabel("time")

plt.subplot(7,1,7)
plt.plot(X[:,6])
plt.ylim(-70,60)
plt.yticks([0,50],size=20)
plt.xticks([0,400,800,1200,1600],size=20)
plt.ylabel("WH",size=20)
#plt.xlabel("time")
plt.xlabel("time",size=20)
# Out:
# Text(0.5, 0, 'time')
